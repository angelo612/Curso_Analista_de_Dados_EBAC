# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Big Data II - Armazenamento
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Introdução;</li>
#   <li>Orientação a coluna;</li>
#   <li>Particionamento.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Particionamento e orientação a coluna.

# %% [markdown]
# Replique as atividades da aula 3 em sua conta da AWS.

# %% [markdown]
# 1.1. Faça o download do arquivo `crime.csv` (fonte [Kaggle](https://www.kaggle.com/yamqwe/chicago-crimee?select=chicago_crime_2014.csv)).

# %%
# !wget https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/dataset/crime.csv -q -O crime.csv

# %% [markdown]
# 1.2. Leia os dados em um DataFrame Pandas e crie a coluna `reference_date`.

# %%
import pandas as pd

filename = './crime'

df = pd.read_csv(f'./{filename}.csv')

# %%
df.head()
# Out:
#    index       ID Case Number                    Date                   Block  \
# 0      0  9446824    HX100141  01/01/2014 02:00:00 AM     0000X W ILLINOIS ST
# 1      1  9446748    HX100020  01/01/2014 12:00:00 AM     006XX N DEARBORN ST
# 2      2  9446758    HX100030  01/01/2014 12:30:00 AM        052XX W RACE AVE
# 3      3  9446760    HX100027  01/01/2014 12:30:00 AM  053XX W WELLINGTON AVE
# 4      4  9446764    HX100054  01/01/2014 12:10:00 AM    014XX W LEXINGTON ST
#
#    IUCR     Primary Type    Description Location Description  Arrest  \
# 0  0460          BATTERY         SIMPLE               STREET   False
# 1  0890            THEFT  FROM BUILDING        BAR OR TAVERN   False
# 2  1310  CRIMINAL DAMAGE    TO PROPERTY            APARTMENT   False
# 3  0460          BATTERY         SIMPLE            APARTMENT    True
# 4  0460          BATTERY         SIMPLE               STREET   False
#
#    Domestic  Beat  District  Ward  Community Area FBI Code   Latitude  \
# 0     False  1831        18  42.0             8.0      08B  41.890828
# 1     False  1832        18  42.0             8.0       06  41.893542
# 2     False  1523        15  28.0            25.0       14  41.890046
# 3     False  2514        25  31.0            19.0      08B  41.935011
# 4     False  1231        12  25.0            28.0      08B  41.872509
#
#    Longitude
# 0 -87.630235
# 1 -87.629702
# 2 -87.756333
# 3 -87.759739
# 4 -87.663069

# %%
# Solução do item 1.2.

# %%
from datetime import datetime

df['reference_date'] = df['Date'].apply(lambda date: datetime.strptime(date.split(sep=' ')[0], '%m/%d/%Y').strftime('%Y-%m-%d'))

# %%
df.head()
# Out:
#    index       ID Case Number                    Date                   Block  \
# 0      0  9446824    HX100141  01/01/2014 02:00:00 AM     0000X W ILLINOIS ST
# 1      1  9446748    HX100020  01/01/2014 12:00:00 AM     006XX N DEARBORN ST
# 2      2  9446758    HX100030  01/01/2014 12:30:00 AM        052XX W RACE AVE
# 3      3  9446760    HX100027  01/01/2014 12:30:00 AM  053XX W WELLINGTON AVE
# 4      4  9446764    HX100054  01/01/2014 12:10:00 AM    014XX W LEXINGTON ST
#
#    IUCR     Primary Type    Description Location Description  Arrest  \
# 0  0460          BATTERY         SIMPLE               STREET   False
# 1  0890            THEFT  FROM BUILDING        BAR OR TAVERN   False
# 2  1310  CRIMINAL DAMAGE    TO PROPERTY            APARTMENT   False
# 3  0460          BATTERY         SIMPLE            APARTMENT    True
# 4  0460          BATTERY         SIMPLE               STREET   False
#
#    Domestic  Beat  District  Ward  Community Area FBI Code   Latitude  \
# 0     False  1831        18  42.0             8.0      08B  41.890828
# 1     False  1832        18  42.0             8.0       06  41.893542
# 2     False  1523        15  28.0            25.0       14  41.890046
# 3     False  2514        25  31.0            19.0      08B  41.935011
# 4     False  1231        12  25.0            28.0      08B  41.872509
#
#    Longitude reference_date
# 0 -87.630235     2014-01-01
# 1 -87.629702     2014-01-01
# 2 -87.756333     2014-01-01
# 3 -87.759739     2014-01-01
# 4 -87.663069     2014-01-01

# %% [markdown]
# 1.3. Persista o dado no DataFrame em um arquivo csv e em arquivos parquet, estes últimos comprimidos e particionados pela coluna `reference_date`.

# %%
agg_df = pd.DataFrame(df['reference_date'].value_counts()).sort_index().reset_index()
agg_df = agg_df.rename(columns={'reference_date': 'amount'})
agg_df = agg_df.rename(columns={'index': 'reference_date'})

# %%
agg_df.head()
# Out:
#   reference_date  amount
# 0     2014-01-01    1057
# 1     2014-01-02     480
# 2     2014-01-03     559
# 3     2014-01-04     576
# 4     2014-01-05     404

# %%
import seaborn as sns

with sns.axes_style('whitegrid'):

  chart = sns.barplot(x='reference_date', y='amount', data=agg_df)
  chart.set(xticklabels=[])
  chart.set(title='Frequency of Crime per Day (Chicago, 2014)', xlabel='Date (values ommited)', ylabel='Absolute Frequency');
  chart.figure.set_size_inches(w=40/2.54, h=15/2.54)

# %%
# Solução do item 1.3.

# %%
df.to_parquet('./crime', engine='pyarrow', compression='gzip', partition_cols='reference_date')

# %%
df.to_csv('./crime_enriched.csv', sep=',', index=False)

# %% [markdown]
# 1.4. Crie os recursos no AWS S3 e AWS IAM e persista os dados em seus respectivos *buckets*.

# %%
# Solução do item 1.4.

# %%
from getpass import getpass

aws_access_key_id = getpass()
# Out:
# ··········

# %%
from getpass import getpass

aws_secret_access_key = getpass()
# Out:
# ··········

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.28.19-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 2.4 MB/s eta 0:00:00
# Collecting botocore<1.32.0,>=1.31.19 (from boto3)
#   Downloading botocore-1.31.19-py3-none-any.whl (11.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 29.9 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3)
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.32.0,>=1.31.19->boto3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.32.0,>=1.31.19->boto3) (1.26.16)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.32.0,>=1.31.19->boto3) (1.16.0)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.28.19 botocore-1.31.19 jmespath-1.0.1 s3transfer-0.6.1

# %%
import boto3

client = boto3.client(
  's3',
  aws_access_key_id=aws_access_key_id,
  aws_secret_access_key=aws_secret_access_key
)

# %%
import os

BUCKET = 'bucket-modulo-42-parquet'

i = 0

for root, dirs, files in os.walk('./crime'):
  elapsed = f'{round(100*i/365, 2)} %'
  print(elapsed)
  for file in files:
    path = os.path.join(root, file)
    bucket_path = '/'.join(path.split(sep='/')[2:])
    client.upload_file(path, BUCKET, bucket_path)
  i = i + 1
# Out:
# 0.0 %
# 0.27 %
# 0.55 %
# 0.82 %
# 1.1 %
# 1.37 %
# 1.64 %
# 1.92 %
# 2.19 %
# 2.47 %
# 2.74 %
# 3.01 %
# 3.29 %
# 3.56 %
# 3.84 %
# 4.11 %
# 4.38 %
# 4.66 %
# 4.93 %
# 5.21 %
# 5.48 %
# 5.75 %
# 6.03 %
# 6.3 %
# 6.58 %
# 6.85 %
# 7.12 %
# 7.4 %
# 7.67 %
# 7.95 %
# 8.22 %
# 8.49 %
# 8.77 %
# 9.04 %
# 9.32 %
# 9.59 %
# 9.86 %
# 10.14 %
# 10.41 %
# 10.68 %
# 10.96 %
# 11.23 %
# 11.51 %
# 11.78 %
# 12.05 %
# 12.33 %
# 12.6 %
# 12.88 %
# 13.15 %
# 13.42 %
# 13.7 %
# 13.97 %
# 14.25 %
# 14.52 %
# 14.79 %
# 15.07 %
# 15.34 %
# 15.62 %
# 15.89 %
# 16.16 %
# 16.44 %
# 16.71 %
# 16.99 %
# 17.26 %
# 17.53 %
# 17.81 %
# 18.08 %
# 18.36 %
# 18.63 %
# 18.9 %
# 19.18 %
# 19.45 %
# 19.73 %
# 20.0 %
# 20.27 %
# 20.55 %
# 20.82 %
# 21.1 %
# 21.37 %
# 21.64 %
# 21.92 %
# 22.19 %
# 22.47 %
# 22.74 %
# 23.01 %
# 23.29 %
# 23.56 %
# 23.84 %
# 24.11 %
# 24.38 %
# 24.66 %
# 24.93 %
# 25.21 %
# 25.48 %
# 25.75 %
# 26.03 %
# 26.3 %
# 26.58 %
# 26.85 %
# 27.12 %
# 27.4 %
# 27.67 %
# 27.95 %
# 28.22 %
# 28.49 %
# 28.77 %
# 29.04 %
# 29.32 %
# 29.59 %
# 29.86 %
# 30.14 %
# 30.41 %
# 30.68 %
# 30.96 %
# 31.23 %
# 31.51 %
# 31.78 %
# 32.05 %
# 32.33 %
# 32.6 %
# 32.88 %
# 33.15 %
# 33.42 %
# 33.7 %
# 33.97 %
# 34.25 %
# 34.52 %
# 34.79 %
# 35.07 %
# 35.34 %
# 35.62 %
# 35.89 %
# 36.16 %
# 36.44 %
# 36.71 %
# 36.99 %
# 37.26 %
# 37.53 %
# 37.81 %
# 38.08 %
# 38.36 %
# 38.63 %
# 38.9 %
# 39.18 %
# 39.45 %
# 39.73 %
# 40.0 %
# 40.27 %
# 40.55 %
# 40.82 %
# 41.1 %
# 41.37 %
# 41.64 %
# 41.92 %
# 42.19 %
# 42.47 %
# 42.74 %
# 43.01 %
# 43.29 %
# 43.56 %
# 43.84 %
# 44.11 %
# 44.38 %
# 44.66 %
# 44.93 %
# 45.21 %
# 45.48 %
# 45.75 %
# 46.03 %
# 46.3 %
# 46.58 %
# 46.85 %
# 47.12 %
# 47.4 %
# 47.67 %
# 47.95 %
# 48.22 %
# 48.49 %
# 48.77 %
# 49.04 %
# 49.32 %
# 49.59 %
# 49.86 %
# 50.14 %
# 50.41 %
# 50.68 %
# 50.96 %
# 51.23 %
# 51.51 %
# 51.78 %
# 52.05 %
# 52.33 %
# 52.6 %
# 52.88 %
# 53.15 %
# 53.42 %
# 53.7 %
# 53.97 %
# 54.25 %
# 54.52 %
# 54.79 %
# 55.07 %
# 55.34 %
# 55.62 %
# 55.89 %
# 56.16 %
# 56.44 %
# 56.71 %
# 56.99 %
# 57.26 %
# 57.53 %
# 57.81 %
# 58.08 %
# 58.36 %
# 58.63 %
# 58.9 %
# 59.18 %
# 59.45 %
# 59.73 %
# 60.0 %
# 60.27 %
# 60.55 %
# 60.82 %
# 61.1 %
# 61.37 %
# 61.64 %
# 61.92 %
# 62.19 %
# 62.47 %
# 62.74 %
# 63.01 %
# 63.29 %
# 63.56 %
# 63.84 %
# 64.11 %
# 64.38 %
# 64.66 %
# 64.93 %
# 65.21 %
# 65.48 %
# 65.75 %
# 66.03 %
# 66.3 %
# 66.58 %
# 66.85 %
# 67.12 %
# 67.4 %
# 67.67 %
# 67.95 %
# 68.22 %
# 68.49 %
# 68.77 %
# 69.04 %
# 69.32 %
# 69.59 %
# 69.86 %
# 70.14 %
# 70.41 %
# 70.68 %
# 70.96 %
# 71.23 %
# 71.51 %
# 71.78 %
# 72.05 %
# 72.33 %
# 72.6 %
# 72.88 %
# 73.15 %
# 73.42 %
# 73.7 %
# 73.97 %
# 74.25 %
# 74.52 %
# 74.79 %
# 75.07 %
# 75.34 %
# 75.62 %
# 75.89 %
# 76.16 %
# 76.44 %
# 76.71 %
# 76.99 %
# 77.26 %
# 77.53 %
# 77.81 %
# 78.08 %
# 78.36 %
# 78.63 %
# 78.9 %
# 79.18 %
# 79.45 %
# 79.73 %
# 80.0 %
# 80.27 %
# 80.55 %
# 80.82 %
# 81.1 %
# 81.37 %
# 81.64 %
# 81.92 %
# 82.19 %
# 82.47 %
# 82.74 %
# 83.01 %
# 83.29 %
# 83.56 %
# 83.84 %
# 84.11 %
# 84.38 %
# 84.66 %
# 84.93 %
# 85.21 %
# 85.48 %
# 85.75 %
# 86.03 %
# 86.3 %
# 86.58 %
# 86.85 %
# 87.12 %
# 87.4 %
# 87.67 %
# 87.95 %
# 88.22 %
# 88.49 %
# 88.77 %
# 89.04 %
# 89.32 %
# 89.59 %
# 89.86 %
# 90.14 %
# 90.41 %
# 90.68 %
# 90.96 %
# 91.23 %
# 91.51 %
# 91.78 %
# 92.05 %
# 92.33 %
# 92.6 %
# 92.88 %
# 93.15 %
# 93.42 %
# 93.7 %
# 93.97 %
# 94.25 %
# 94.52 %
# 94.79 %
# 95.07 %
# 95.34 %
# 95.62 %
# 95.89 %
# 96.16 %
# 96.44 %
# 96.71 %
# 96.99 %
# 97.26 %
# 97.53 %
# 97.81 %
# 98.08 %
# 98.36 %
# 98.63 %
# 98.9 %
# 99.18 %
# 99.45 %
# 99.73 %
# 100.0 %

# %% [markdown]
# 1.5. Crie os recursos no AWS Athena e execute as consultas SQL da aula.

# %%
# Solução do item 1.5.
